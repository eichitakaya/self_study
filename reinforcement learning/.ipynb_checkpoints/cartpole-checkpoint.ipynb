# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis("off")
    
    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save("movie_cartpole.mp4")
    display(display_animation(anim, default_mode="loop"))

# %%
# random movement in CartPole

frames = []
env = gym.make("CartPole-v0")
observation = env.reset()

for step in range(0, 200):
    frames.append(env.render(mode="rgb_array"))
    action = np.random.choice(2)
    observation, reward, done, info = env.step(action)

# %%
display_frames_as_gif(frames)

# %%
# dizitize state

ENV = "CartPole-v0"
NUM_DIZITIZED = 6

env = gym.make(ENV)
observation = env.reset()

# %%
observation

# %%
def bins(clip_min, clip_max, num):
    return np.linspace(clip_min, clip_max, num + 1)[1:-1]

# %%
def digitize_state(observation):
    cart_pos, cart_v, pole_angle, pole_v = observaton
    digitized = [
        np.digitize(cart_pos, bins=bins(-2.4, 2.4, NUM_DIZITIZED)),
        np.digitize(cart_v, bins=bins(-3.0, 3.0, NUM_DIZITIZED)),
        np.digitize(pole_angle, bins=bins(-0.5, 0.5, NUM_DIZITIZED)),
        np.digitize(pole_v, bins=bins(-2.0, 2.0, NUM_DIZITIZED))
    ]
    return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

ENV = "CartPole-v0"
NUM_DIZITIZED = 6
GAMMA = 0.99
ETA = 0.5
MAX_STEPS = 200
NUM_EPISODES = 1000

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
    
    def update_Q_function(self, observation, action, reward, observation_next):
        self.brain.update_Q_table(observation, action, reward, observation_next)
    
    def get_action(self, observation, step):
        action = self.brain.decide_action(observation, step)
        return action

# %%
class Brain:
    
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))
    
    def bins(self, clip_min, clip_max, num):
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]
    
    def digitize_state(self, observation):
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        state = self.digitize_state(observation)
        state_next = self.digitize_state(observation_next)
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + ETA * (reward + GAMMA * Max_Q_next - self.q_table[state, action])
        
    def decide_action(self, observation, episode):
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
        return action

# %%
class Environment:
    
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n  
        self.agent = Agent(num_states, num_actions)
    
    def run(self):
        complete_episodes = 0
        is_episode_final = False
        frames = []
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            
            for step in range(MAX_STEPS):
                
                if is_episode_final is True:
                    frames.append(self.env.render(mode="rgb_array"))
                    
                action = self.agent.get_action(observation, episode)
                
                observation_next, _, done, _ = self.env.step(action)
                
                if done:
                    if step < 195:
                        reward = -1
                        complete_episodes = 0
                    else:
                        reward = 1
                        complete_episodes += 1
                else:
                    reward = 0
                
                self.agent.update_Q_function(observation, action, reward, observation_next)
                
                observation = observation_next
                
                if done:
                    print("{0} Episode: Finished after {1} time steps".format(episode, step + 1))
                    break

            if is_episode_final is True:
                display_frames_as_gif(frames)
                break
            
            if complete_episodes >= 10:
                print("great!")
                is_episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# 0 Episode: Finished after 15 time steps
# 1 Episode: Finished after 11 time steps
# 2 Episode: Finished after 10 time steps
# 3 Episode: Finished after 24 time steps
# 4 Episode: Finished after 9 time steps
# 5 Episode: Finished after 17 time steps
# 6 Episode: Finished after 10 time steps
# 7 Episode: Finished after 9 time steps
# 8 Episode: Finished after 8 time steps
# 9 Episode: Finished after 11 time steps
# 10 Episode: Finished after 10 time steps
# 11 Episode: Finished after 10 time steps
# 12 Episode: Finished after 10 time steps
# 13 Episode: Finished after 9 time steps
# 14 Episode: Finished after 10 time steps
# 15 Episode: Finished after 9 time steps
# 16 Episode: Finished after 10 time steps
# 17 Episode: Finished after 10 time steps
# 18 Episode: Finished after 10 time steps
# 19 Episode: Finished after 9 time steps
# 20 Episode: Finished after 10 time steps
# 21 Episode: Finished after 10 time steps
# 22 Episode: Finished after 9 time steps
# 23 Episode: Finished after 10 time steps
# 24 Episode: Finished after 9 time steps
# 25 Episode: Finished after 9 time steps
# 26 Episode: Finished after 8 time steps
# 27 Episode: Finished after 10 time steps
# 28 Episode: Finished after 10 time steps
# 29 Episode: Finished after 10 time steps
# 30 Episode: Finished after 10 time steps
# 31 Episode: Finished after 9 time steps
# 32 Episode: Finished after 10 time steps
# 33 Episode: Finished after 9 time steps
# 34 Episode: Finished after 10 time steps
# 35 Episode: Finished after 9 time steps
# 36 Episode: Finished after 8 time steps
# 37 Episode: Finished after 9 time steps
# 38 Episode: Finished after 9 time steps
# 39 Episode: Finished after 9 time steps
# 40 Episode: Finished after 11 time steps
# 41 Episode: Finished after 9 time steps
# 42 Episode: Finished after 10 time steps
# 43 Episode: Finished after 12 time steps
# 44 Episode: Finished after 10 time steps
# 45 Episode: Finished after 9 time steps
# 46 Episode: Finished after 9 time steps
# 47 Episode: Finished after 10 time steps
# 48 Episode: Finished after 9 time steps
# 49 Episode: Finished after 9 time steps
# 50 Episode: Finished after 9 time steps
# 51 Episode: Finished after 10 time steps
# 52 Episode: Finished after 10 time steps
# 53 Episode: Finished after 8 time steps
# 54 Episode: Finished after 10 time steps
# 55 Episode: Finished after 10 time steps
# 56 Episode: Finished after 10 time steps
# 57 Episode: Finished after 9 time steps
# 58 Episode: Finished after 9 time steps
# 59 Episode: Finished after 9 time steps
# 60 Episode: Finished after 10 time steps
# 61 Episode: Finished after 8 time steps
# 62 Episode: Finished after 10 time steps
# 63 Episode: Finished after 10 time steps
# 64 Episode: Finished after 10 time steps
# 65 Episode: Finished after 9 time steps
# 66 Episode: Finished after 10 time steps
# 67 Episode: Finished after 10 time steps
# 68 Episode: Finished after 10 time steps
# 69 Episode: Finished after 9 time steps
# 70 Episode: Finished after 9 time steps
# 71 Episode: Finished after 9 time steps
# 72 Episode: Finished after 10 time steps
# 73 Episode: Finished after 10 time steps
# 74 Episode: Finished after 8 time steps
# 75 Episode: Finished after 9 time steps
# 76 Episode: Finished after 8 time steps
# 77 Episode: Finished after 8 time steps
# 78 Episode: Finished after 8 time steps
# 79 Episode: Finished after 9 time steps
# 80 Episode: Finished after 9 time steps
# 81 Episode: Finished after 10 time steps
# 82 Episode: Finished after 9 time steps
# 83 Episode: Finished after 9 time steps
# 84 Episode: Finished after 10 time steps
# 85 Episode: Finished after 10 time steps
# 86 Episode: Finished after 9 time steps
# 87 Episode: Finished after 10 time steps
# 88 Episode: Finished after 9 time steps
# 89 Episode: Finished after 10 time steps
# 90 Episode: Finished after 9 time steps
# 91 Episode: Finished after 10 time steps
# 92 Episode: Finished after 11 time steps
# 93 Episode: Finished after 8 time steps
# 94 Episode: Finished after 9 time steps
# 95 Episode: Finished after 9 time steps
# 96 Episode: Finished after 10 time steps
# 97 Episode: Finished after 10 time steps
# 98 Episode: Finished after 11 time steps
# 99 Episode: Finished after 10 time steps
# 100 Episode: Finished after 9 time steps
# 101 Episode: Finished after 9 time steps
# 102 Episode: Finished after 9 time steps
# 103 Episode: Finished after 10 time steps
# 104 Episode: Finished after 9 time steps
# 105 Episode: Finished after 10 time steps
# 106 Episode: Finished after 9 time steps
# 107 Episode: Finished after 9 time steps
# 108 Episode: Finished after 9 time steps
# 109 Episode: Finished after 8 time steps
# 110 Episode: Finished after 9 time steps
# 111 Episode: Finished after 8 time steps
# 112 Episode: Finished after 10 time steps
# 113 Episode: Finished after 9 time steps
# 114 Episode: Finished after 10 time steps
# 115 Episode: Finished after 10 time steps
# 116 Episode: Finished after 9 time steps
# 117 Episode: Finished after 10 time steps
# 118 Episode: Finished after 8 time steps
# 119 Episode: Finished after 9 time steps
# 120 Episode: Finished after 10 time steps
# 121 Episode: Finished after 10 time steps
# 122 Episode: Finished after 9 time steps
# 123 Episode: Finished after 9 time steps
# 124 Episode: Finished after 9 time steps
# 125 Episode: Finished after 10 time steps
# 126 Episode: Finished after 10 time steps
# 127 Episode: Finished after 9 time steps
# 128 Episode: Finished after 9 time steps
# 129 Episode: Finished after 10 time steps
# 130 Episode: Finished after 9 time steps
# 131 Episode: Finished after 9 time steps
# 132 Episode: Finished after 10 time steps
# 133 Episode: Finished after 9 time steps
# 134 Episode: Finished after 9 time steps
# 135 Episode: Finished after 9 time steps
# 136 Episode: Finished after 10 time steps
# 137 Episode: Finished after 10 time steps
# 138 Episode: Finished after 10 time steps
# 139 Episode: Finished after 8 time steps
# 140 Episode: Finished after 9 time steps
# 141 Episode: Finished after 9 time steps
# 142 Episode: Finished after 11 time steps
# 143 Episode: Finished after 9 time steps
# 144 Episode: Finished after 10 time steps
# 145 Episode: Finished after 9 time steps
# 146 Episode: Finished after 10 time steps
# 147 Episode: Finished after 9 time steps
# 148 Episode: Finished after 8 time steps
# 149 Episode: Finished after 9 time steps
# 150 Episode: Finished after 9 time steps
# 151 Episode: Finished after 9 time steps
# 152 Episode: Finished after 11 time steps
# 153 Episode: Finished after 10 time steps
# 154 Episode: Finished after 9 time steps
# 155 Episode: Finished after 9 time steps
# 156 Episode: Finished after 10 time steps
# 157 Episode: Finished after 9 time steps
# 158 Episode: Finished after 9 time steps
# 159 Episode: Finished after 10 time steps
# 160 Episode: Finished after 9 time steps
# 161 Episode: Finished after 9 time steps
# 162 Episode: Finished after 10 time steps
# 163 Episode: Finished after 8 time steps
# 164 Episode: Finished after 9 time steps
# 165 Episode: Finished after 10 time steps
# 166 Episode: Finished after 9 time steps
# 167 Episode: Finished after 8 time steps
# 168 Episode: Finished after 10 time steps
# 169 Episode: Finished after 10 time steps
# 170 Episode: Finished after 10 time steps
# 171 Episode: Finished after 10 time steps
# 172 Episode: Finished after 9 time steps
# 173 Episode: Finished after 8 time steps
# 174 Episode: Finished after 9 time steps
# 175 Episode: Finished after 10 time steps
# 176 Episode: Finished after 10 time steps
# 177 Episode: Finished after 9 time steps
# 178 Episode: Finished after 8 time steps
# 179 Episode: Finished after 9 time steps
# 180 Episode: Finished after 9 time steps
# 181 Episode: Finished after 8 time steps
# 182 Episode: Finished after 12 time steps
# 183 Episode: Finished after 8 time steps
# 184 Episode: Finished after 8 time steps
# 185 Episode: Finished after 10 time steps
# 186 Episode: Finished after 10 time steps
# 187 Episode: Finished after 8 time steps
# 188 Episode: Finished after 10 time steps
# 189 Episode: Finished after 10 time steps
# 190 Episode: Finished after 10 time steps
# 191 Episode: Finished after 9 time steps
# 192 Episode: Finished after 9 time steps
# 193 Episode: Finished after 9 time steps
# 194 Episode: Finished after 10 time steps
# 195 Episode: Finished after 10 time steps
# 196 Episode: Finished after 13 time steps
# 197 Episode: Finished after 9 time steps
# 198 Episode: Finished after 8 time steps
# 199 Episode: Finished after 9 time steps
# 200 Episode: Finished after 9 time steps
# 201 Episode: Finished after 10 time steps
# 202 Episode: Finished after 10 time steps
# 203 Episode: Finished after 9 time steps
# 204 Episode: Finished after 9 time steps
# 205 Episode: Finished after 10 time steps
# 206 Episode: Finished after 9 time steps
# 207 Episode: Finished after 9 time steps
# 208 Episode: Finished after 10 time steps
# 209 Episode: Finished after 9 time steps
# 210 Episode: Finished after 10 time steps
# 211 Episode: Finished after 8 time steps
# 212 Episode: Finished after 10 time steps
# 213 Episode: Finished after 9 time steps
# 214 Episode: Finished after 8 time steps
# 215 Episode: Finished after 9 time steps
# 216 Episode: Finished after 11 time steps
# 217 Episode: Finished after 9 time steps
# 218 Episode: Finished after 9 time steps
# 219 Episode: Finished after 9 time steps
# 220 Episode: Finished after 9 time steps
# 221 Episode: Finished after 9 time steps
# 222 Episode: Finished after 8 time steps
# 223 Episode: Finished after 9 time steps
# 224 Episode: Finished after 9 time steps
# 225 Episode: Finished after 10 time steps
# 226 Episode: Finished after 10 time steps
# 227 Episode: Finished after 8 time steps
# 228 Episode: Finished after 10 time steps
# 229 Episode: Finished after 9 time steps
# 230 Episode: Finished after 10 time steps
# 231 Episode: Finished after 9 time steps
# 232 Episode: Finished after 10 time steps
# 233 Episode: Finished after 9 time steps
# 234 Episode: Finished after 9 time steps
# 235 Episode: Finished after 9 time steps
# 236 Episode: Finished after 10 time steps
# 237 Episode: Finished after 10 time steps
# 238 Episode: Finished after 10 time steps
# 239 Episode: Finished after 9 time steps
# 240 Episode: Finished after 9 time steps
# 241 Episode: Finished after 8 time steps
# 242 Episode: Finished after 9 time steps
# 243 Episode: Finished after 9 time steps
# 244 Episode: Finished after 10 time steps
# 245 Episode: Finished after 8 time steps
# 246 Episode: Finished after 11 time steps
# 247 Episode: Finished after 10 time steps
# 248 Episode: Finished after 8 time steps
# 249 Episode: Finished after 9 time steps
# 250 Episode: Finished after 9 time steps
# 251 Episode: Finished after 9 time steps
# 252 Episode: Finished after 9 time steps
# 253 Episode: Finished after 10 time steps
# 254 Episode: Finished after 9 time steps
# 255 Episode: Finished after 9 time steps
# 256 Episode: Finished after 8 time steps
# 257 Episode: Finished after 10 time steps
# 258 Episode: Finished after 9 time steps
# 259 Episode: Finished after 9 time steps
# 260 Episode: Finished after 10 time steps
# 261 Episode: Finished after 11 time steps
# 262 Episode: Finished after 9 time steps
# 263 Episode: Finished after 10 time steps
# 264 Episode: Finished after 8 time steps
# 265 Episode: Finished after 10 time steps
# 266 Episode: Finished after 9 time steps
# 267 Episode: Finished after 10 time steps
# 268 Episode: Finished after 9 time steps
# 269 Episode: Finished after 10 time steps
# 270 Episode: Finished after 9 time steps
# 271 Episode: Finished after 10 time steps
# 272 Episode: Finished after 10 time steps
# 273 Episode: Finished after 10 time steps
# 274 Episode: Finished after 9 time steps
# 275 Episode: Finished after 8 time steps
# 276 Episode: Finished after 10 time steps
# 277 Episode: Finished after 9 time steps
# 278 Episode: Finished after 11 time steps
# 279 Episode: Finished after 8 time steps
# 280 Episode: Finished after 10 time steps
# 281 Episode: Finished after 9 time steps
# 282 Episode: Finished after 11 time steps
# 283 Episode: Finished after 8 time steps
# 284 Episode: Finished after 9 time steps
# 285 Episode: Finished after 10 time steps
# 286 Episode: Finished after 9 time steps
# 287 Episode: Finished after 9 time steps
# 288 Episode: Finished after 10 time steps
# 289 Episode: Finished after 10 time steps
# 290 Episode: Finished after 9 time steps
# 291 Episode: Finished after 10 time steps
# 292 Episode: Finished after 10 time steps
# 293 Episode: Finished after 10 time steps
# 294 Episode: Finished after 11 time steps
# 295 Episode: Finished after 9 time steps
# 296 Episode: Finished after 11 time steps
# 297 Episode: Finished after 9 time steps
# 298 Episode: Finished after 9 time steps
# 299 Episode: Finished after 9 time steps
# 300 Episode: Finished after 10 time steps
# 301 Episode: Finished after 10 time steps
# 302 Episode: Finished after 9 time steps
# 303 Episode: Finished after 10 time steps
# 304 Episode: Finished after 9 time steps
# 305 Episode: Finished after 9 time steps
# 306 Episode: Finished after 8 time steps
# 307 Episode: Finished after 10 time steps
# 308 Episode: Finished after 10 time steps
# 309 Episode: Finished after 10 time steps
# 310 Episode: Finished after 9 time steps
# 311 Episode: Finished after 10 time steps
# 312 Episode: Finished after 9 time steps
# 313 Episode: Finished after 9 time steps
# 314 Episode: Finished after 10 time steps
# 315 Episode: Finished after 9 time steps
# 316 Episode: Finished after 10 time steps
# 317 Episode: Finished after 10 time steps
# 318 Episode: Finished after 10 time steps
# 319 Episode: Finished after 9 time steps
# 320 Episode: Finished after 10 time steps
# 321 Episode: Finished after 10 time steps
# 322 Episode: Finished after 8 time steps
# 323 Episode: Finished after 9 time steps
# 324 Episode: Finished after 10 time steps
# 325 Episode: Finished after 9 time steps
# 326 Episode: Finished after 9 time steps
# 327 Episode: Finished after 8 time steps
# 328 Episode: Finished after 10 time steps
# 329 Episode: Finished after 9 time steps
# 330 Episode: Finished after 10 time steps
# 331 Episode: Finished after 9 time steps
# 332 Episode: Finished after 9 time steps
# 333 Episode: Finished after 9 time steps
# 334 Episode: Finished after 10 time steps
# 335 Episode: Finished after 10 time steps
# 336 Episode: Finished after 10 time steps
# 337 Episode: Finished after 10 time steps
# 338 Episode: Finished after 8 time steps
# 339 Episode: Finished after 8 time steps
# 340 Episode: Finished after 10 time steps
# 341 Episode: Finished after 10 time steps
# 342 Episode: Finished after 9 time steps
# 343 Episode: Finished after 8 time steps
# 344 Episode: Finished after 9 time steps
# 345 Episode: Finished after 10 time steps
# 346 Episode: Finished after 10 time steps
# 347 Episode: Finished after 9 time steps
# 348 Episode: Finished after 9 time steps
# 349 Episode: Finished after 10 time steps
# 350 Episode: Finished after 8 time steps
# 351 Episode: Finished after 10 time steps
# 352 Episode: Finished after 8 time steps
# 353 Episode: Finished after 9 time steps
# 354 Episode: Finished after 9 time steps
# 355 Episode: Finished after 9 time steps
# 356 Episode: Finished after 9 time steps
# 357 Episode: Finished after 9 time steps
# 358 Episode: Finished after 10 time steps
# 359 Episode: Finished after 9 time steps
# 360 Episode: Finished after 9 time steps
# 361 Episode: Finished after 8 time steps
# 362 Episode: Finished after 9 time steps
# 363 Episode: Finished after 10 time steps
# 364 Episode: Finished after 10 time steps
# 365 Episode: Finished after 10 time steps
# 366 Episode: Finished after 9 time steps
# 367 Episode: Finished after 9 time steps
# 368 Episode: Finished after 10 time steps
# 369 Episode: Finished after 9 time steps
# 370 Episode: Finished after 9 time steps
# 371 Episode: Finished after 9 time steps
# 372 Episode: Finished after 10 time steps
# 373 Episode: Finished after 9 time steps
# 374 Episode: Finished after 8 time steps
# 375 Episode: Finished after 9 time steps
# 376 Episode: Finished after 10 time steps
# 377 Episode: Finished after 10 time steps
# 378 Episode: Finished after 9 time steps
# 379 Episode: Finished after 9 time steps
# 380 Episode: Finished after 9 time steps
# 381 Episode: Finished after 8 time steps
# 382 Episode: Finished after 10 time steps
# 383 Episode: Finished after 9 time steps
# 384 Episode: Finished after 10 time steps
# 385 Episode: Finished after 10 time steps
# 386 Episode: Finished after 9 time steps
# 387 Episode: Finished after 11 time steps
# 388 Episode: Finished after 9 time steps
# 389 Episode: Finished after 11 time steps
# 390 Episode: Finished after 10 time steps
# 391 Episode: Finished after 9 time steps
# 392 Episode: Finished after 10 time steps
# 393 Episode: Finished after 8 time steps
# 394 Episode: Finished after 8 time steps
# 395 Episode: Finished after 10 time steps
# 396 Episode: Finished after 9 time steps
# 397 Episode: Finished after 10 time steps
# 398 Episode: Finished after 10 time steps
# 399 Episode: Finished after 9 time steps
# 400 Episode: Finished after 9 time steps
# 401 Episode: Finished after 11 time steps
# 402 Episode: Finished after 10 time steps
# 403 Episode: Finished after 8 time steps
# 404 Episode: Finished after 9 time steps
# 405 Episode: Finished after 9 time steps
# 406 Episode: Finished after 9 time steps
# 407 Episode: Finished after 8 time steps
# 408 Episode: Finished after 10 time steps
# 409 Episode: Finished after 8 time steps
# 410 Episode: Finished after 9 time steps
# 411 Episode: Finished after 10 time steps
# 412 Episode: Finished after 9 time steps
# 413 Episode: Finished after 10 time steps
# 414 Episode: Finished after 10 time steps
# 415 Episode: Finished after 9 time steps
# 416 Episode: Finished after 10 time steps
# 417 Episode: Finished after 8 time steps
# 418 Episode: Finished after 9 time steps
# 419 Episode: Finished after 10 time steps
# 420 Episode: Finished after 9 time steps
# 421 Episode: Finished after 10 time steps
# 422 Episode: Finished after 8 time steps
# 423 Episode: Finished after 10 time steps
# 424 Episode: Finished after 9 time steps
# 425 Episode: Finished after 9 time steps
# 426 Episode: Finished after 9 time steps
# 427 Episode: Finished after 8 time steps
# 428 Episode: Finished after 11 time steps
# 429 Episode: Finished after 9 time steps
# 430 Episode: Finished after 10 time steps
# 431 Episode: Finished after 11 time steps
# 432 Episode: Finished after 10 time steps
# 433 Episode: Finished after 10 time steps
# 434 Episode: Finished after 9 time steps
# 435 Episode: Finished after 10 time steps
# 436 Episode: Finished after 10 time steps
# 437 Episode: Finished after 9 time steps
# 438 Episode: Finished after 9 time steps
# 439 Episode: Finished after 8 time steps
# 440 Episode: Finished after 8 time steps
# 441 Episode: Finished after 9 time steps
# 442 Episode: Finished after 9 time steps
# 443 Episode: Finished after 10 time steps
# 444 Episode: Finished after 11 time steps
# 445 Episode: Finished after 9 time steps
# 446 Episode: Finished after 10 time steps
# 447 Episode: Finished after 8 time steps
# 448 Episode: Finished after 9 time steps
# 449 Episode: Finished after 9 time steps
# 450 Episode: Finished after 9 time steps
# 451 Episode: Finished after 9 time steps
# 452 Episode: Finished after 9 time steps
# 453 Episode: Finished after 9 time steps
# 454 Episode: Finished after 9 time steps
# 455 Episode: Finished after 10 time steps
# 456 Episode: Finished after 10 time steps
# 457 Episode: Finished after 9 time steps
# 458 Episode: Finished after 8 time steps
# 459 Episode: Finished after 9 time steps
# 460 Episode: Finished after 10 time steps
# 461 Episode: Finished after 10 time steps
# 462 Episode: Finished after 9 time steps
# 463 Episode: Finished after 10 time steps
# 464 Episode: Finished after 8 time steps
# 465 Episode: Finished after 10 time steps
# 466 Episode: Finished after 9 time steps
# 467 Episode: Finished after 13 time steps
# 468 Episode: Finished after 10 time steps
# 469 Episode: Finished after 10 time steps
# 470 Episode: Finished after 10 time steps
# 471 Episode: Finished after 10 time steps
# 472 Episode: Finished after 10 time steps
# 473 Episode: Finished after 10 time steps
# 474 Episode: Finished after 9 time steps
# 475 Episode: Finished after 9 time steps
# 476 Episode: Finished after 9 time steps
# 477 Episode: Finished after 9 time steps
# 478 Episode: Finished after 9 time steps
# 479 Episode: Finished after 10 time steps
# 480 Episode: Finished after 10 time steps
# 481 Episode: Finished after 11 time steps
# 482 Episode: Finished after 9 time steps
# 483 Episode: Finished after 10 time steps
# 484 Episode: Finished after 9 time steps
# 485 Episode: Finished after 9 time steps
# 486 Episode: Finished after 11 time steps
# 487 Episode: Finished after 9 time steps
# 488 Episode: Finished after 9 time steps
# 489 Episode: Finished after 10 time steps
# 490 Episode: Finished after 10 time steps
# 491 Episode: Finished after 9 time steps
# 492 Episode: Finished after 9 time steps
# 493 Episode: Finished after 8 time steps
# 494 Episode: Finished after 10 time steps
# 495 Episode: Finished after 8 time steps
# 496 Episode: Finished after 8 time steps
# 497 Episode: Finished after 9 time steps
# 498 Episode: Finished after 10 time steps
# 499 Episode: Finished after 9 time steps
# 500 Episode: Finished after 9 time steps
# 501 Episode: Finished after 10 time steps
# 502 Episode: Finished after 8 time steps
# 503 Episode: Finished after 9 time steps
# 504 Episode: Finished after 9 time steps
# 505 Episode: Finished after 8 time steps
# 506 Episode: Finished after 10 time steps
# 507 Episode: Finished after 8 time steps
# 508 Episode: Finished after 10 time steps
# 509 Episode: Finished after 9 time steps
# 510 Episode: Finished after 9 time steps
# 511 Episode: Finished after 9 time steps
# 512 Episode: Finished after 9 time steps
# 513 Episode: Finished after 9 time steps
# 514 Episode: Finished after 9 time steps
# 515 Episode: Finished after 10 time steps
# 516 Episode: Finished after 10 time steps
# 517 Episode: Finished after 10 time steps
# 518 Episode: Finished after 9 time steps
# 519 Episode: Finished after 9 time steps
# 520 Episode: Finished after 10 time steps
# 521 Episode: Finished after 10 time steps
# 522 Episode: Finished after 10 time steps
# 523 Episode: Finished after 9 time steps
# 524 Episode: Finished after 11 time steps
# 525 Episode: Finished after 9 time steps
# 526 Episode: Finished after 11 time steps
# 527 Episode: Finished after 9 time steps
# 528 Episode: Finished after 8 time steps
# 529 Episode: Finished after 8 time steps
# 530 Episode: Finished after 10 time steps
# 531 Episode: Finished after 9 time steps
# 532 Episode: Finished after 9 time steps
# 533 Episode: Finished after 10 time steps
# 534 Episode: Finished after 10 time steps
# 535 Episode: Finished after 10 time steps
# 536 Episode: Finished after 10 time steps
# 537 Episode: Finished after 10 time steps
# 538 Episode: Finished after 10 time steps
# 539 Episode: Finished after 9 time steps
# 540 Episode: Finished after 9 time steps
# 541 Episode: Finished after 10 time steps
# 542 Episode: Finished after 10 time steps
# 543 Episode: Finished after 9 time steps
# 544 Episode: Finished after 9 time steps
# 545 Episode: Finished after 10 time steps
# 546 Episode: Finished after 10 time steps
# 547 Episode: Finished after 10 time steps
# 548 Episode: Finished after 8 time steps
# 549 Episode: Finished after 9 time steps
# 550 Episode: Finished after 9 time steps
# 551 Episode: Finished after 9 time steps
# 552 Episode: Finished after 10 time steps
# 553 Episode: Finished after 11 time steps
# 554 Episode: Finished after 10 time steps
# 555 Episode: Finished after 9 time steps
# 556 Episode: Finished after 10 time steps
# 557 Episode: Finished after 10 time steps
# 558 Episode: Finished after 10 time steps
# 559 Episode: Finished after 9 time steps
# 560 Episode: Finished after 10 time steps
# 561 Episode: Finished after 10 time steps
# 562 Episode: Finished after 11 time steps
# 563 Episode: Finished after 10 time steps
# 564 Episode: Finished after 9 time steps
# 565 Episode: Finished after 9 time steps
# 566 Episode: Finished after 9 time steps
# 567 Episode: Finished after 8 time steps
# 568 Episode: Finished after 9 time steps
# 569 Episode: Finished after 9 time steps
# 570 Episode: Finished after 10 time steps
# 571 Episode: Finished after 10 time steps
# 572 Episode: Finished after 10 time steps
# 573 Episode: Finished after 10 time steps
# 574 Episode: Finished after 10 time steps
# 575 Episode: Finished after 9 time steps
# 576 Episode: Finished after 9 time steps
# 577 Episode: Finished after 11 time steps
# 578 Episode: Finished after 10 time steps
# 579 Episode: Finished after 9 time steps
# 580 Episode: Finished after 9 time steps
# 581 Episode: Finished after 10 time steps
# 582 Episode: Finished after 10 time steps
# 583 Episode: Finished after 10 time steps
# 584 Episode: Finished after 9 time steps
# 585 Episode: Finished after 8 time steps
# 586 Episode: Finished after 9 time steps
# 587 Episode: Finished after 9 time steps
# 588 Episode: Finished after 10 time steps
# 589 Episode: Finished after 8 time steps
# 590 Episode: Finished after 9 time steps
# 591 Episode: Finished after 9 time steps
# 592 Episode: Finished after 8 time steps
# 593 Episode: Finished after 8 time steps
# 594 Episode: Finished after 10 time steps
# 595 Episode: Finished after 9 time steps
# 596 Episode: Finished after 10 time steps
# 597 Episode: Finished after 10 time steps
# 598 Episode: Finished after 9 time steps
# 599 Episode: Finished after 9 time steps
# 600 Episode: Finished after 9 time steps
# 601 Episode: Finished after 11 time steps
# 602 Episode: Finished after 10 time steps
# 603 Episode: Finished after 10 time steps
# 604 Episode: Finished after 9 time steps
# 605 Episode: Finished after 9 time steps
# 606 Episode: Finished after 9 time steps
# 607 Episode: Finished after 9 time steps
# 608 Episode: Finished after 8 time steps
# 609 Episode: Finished after 10 time steps
# 610 Episode: Finished after 10 time steps
# 611 Episode: Finished after 10 time steps
# 612 Episode: Finished after 8 time steps
# 613 Episode: Finished after 9 time steps
# 614 Episode: Finished after 10 time steps
# 615 Episode: Finished after 11 time steps
# 616 Episode: Finished after 9 time steps
# 617 Episode: Finished after 9 time steps
# 618 Episode: Finished after 8 time steps
# 619 Episode: Finished after 10 time steps
# 620 Episode: Finished after 10 time steps
# 621 Episode: Finished after 10 time steps
# 622 Episode: Finished after 8 time steps
# 623 Episode: Finished after 10 time steps
# 624 Episode: Finished after 10 time steps
# 625 Episode: Finished after 8 time steps
# 626 Episode: Finished after 11 time steps
# 627 Episode: Finished after 9 time steps
# 628 Episode: Finished after 10 time steps
# 629 Episode: Finished after 9 time steps
# 630 Episode: Finished after 8 time steps
# 631 Episode: Finished after 10 time steps
# 632 Episode: Finished after 9 time steps
# 633 Episode: Finished after 10 time steps
# 634 Episode: Finished after 9 time steps
# 635 Episode: Finished after 9 time steps
# 636 Episode: Finished after 10 time steps
# 637 Episode: Finished after 8 time steps
# 638 Episode: Finished after 10 time steps
# 639 Episode: Finished after 10 time steps
# 640 Episode: Finished after 9 time steps
# 641 Episode: Finished after 9 time steps
# 642 Episode: Finished after 10 time steps
# 643 Episode: Finished after 10 time steps
# 644 Episode: Finished after 11 time steps
# 645 Episode: Finished after 9 time steps
# 646 Episode: Finished after 9 time steps
# 647 Episode: Finished after 9 time steps
# 648 Episode: Finished after 10 time steps
# 649 Episode: Finished after 10 time steps
# 650 Episode: Finished after 9 time steps
# 651 Episode: Finished after 9 time steps
# 652 Episode: Finished after 10 time steps
# 653 Episode: Finished after 10 time steps
# 654 Episode: Finished after 10 time steps
# 655 Episode: Finished after 10 time steps
# 656 Episode: Finished after 10 time steps
# 657 Episode: Finished after 8 time steps
# 658 Episode: Finished after 10 time steps
# 659 Episode: Finished after 8 time steps
# 660 Episode: Finished after 9 time steps
# 661 Episode: Finished after 10 time steps
# 662 Episode: Finished after 10 time steps
# 663 Episode: Finished after 9 time steps
# 664 Episode: Finished after 10 time steps
# 665 Episode: Finished after 8 time steps
# 666 Episode: Finished after 10 time steps
# 667 Episode: Finished after 10 time steps
# 668 Episode: Finished after 9 time steps
# 669 Episode: Finished after 10 time steps
# 670 Episode: Finished after 10 time steps
# 671 Episode: Finished after 10 time steps
# 672 Episode: Finished after 9 time steps
# 673 Episode: Finished after 10 time steps
# 674 Episode: Finished after 9 time steps
# 675 Episode: Finished after 10 time steps
# 676 Episode: Finished after 8 time steps
# 677 Episode: Finished after 10 time steps
# 678 Episode: Finished after 10 time steps
# 679 Episode: Finished after 10 time steps
# 680 Episode: Finished after 10 time steps
# 681 Episode: Finished after 9 time steps
# 682 Episode: Finished after 9 time steps
# 683 Episode: Finished after 8 time steps
# 684 Episode: Finished after 8 time steps
# 685 Episode: Finished after 10 time steps
# 686 Episode: Finished after 9 time steps
# 687 Episode: Finished after 8 time steps
# 688 Episode: Finished after 9 time steps
# 689 Episode: Finished after 10 time steps
# 690 Episode: Finished after 9 time steps
# 691 Episode: Finished after 9 time steps
# 692 Episode: Finished after 8 time steps
# 693 Episode: Finished after 9 time steps
# 694 Episode: Finished after 9 time steps
# 695 Episode: Finished after 10 time steps
# 696 Episode: Finished after 10 time steps
# 697 Episode: Finished after 10 time steps
# 698 Episode: Finished after 10 time steps
# 699 Episode: Finished after 10 time steps
# 700 Episode: Finished after 9 time steps
# 701 Episode: Finished after 9 time steps
# 702 Episode: Finished after 10 time steps
# 703 Episode: Finished after 11 time steps
# 704 Episode: Finished after 10 time steps
# 705 Episode: Finished after 9 time steps
# 706 Episode: Finished after 9 time steps
# 707 Episode: Finished after 10 time steps
# 708 Episode: Finished after 9 time steps
# 709 Episode: Finished after 10 time steps
# 710 Episode: Finished after 10 time steps
# 711 Episode: Finished after 10 time steps
# 712 Episode: Finished after 9 time steps
# 713 Episode: Finished after 9 time steps
# 714 Episode: Finished after 9 time steps
# 715 Episode: Finished after 9 time steps
# 716 Episode: Finished after 9 time steps
# 717 Episode: Finished after 8 time steps
# 718 Episode: Finished after 10 time steps
# 719 Episode: Finished after 10 time steps
# 720 Episode: Finished after 9 time steps
# 721 Episode: Finished after 10 time steps
# 722 Episode: Finished after 10 time steps
# 723 Episode: Finished after 10 time steps
# 724 Episode: Finished after 9 time steps
# 725 Episode: Finished after 9 time steps
# 726 Episode: Finished after 10 time steps
# 727 Episode: Finished after 10 time steps
# 728 Episode: Finished after 8 time steps
# 729 Episode: Finished after 10 time steps
# 730 Episode: Finished after 9 time steps
# 731 Episode: Finished after 9 time steps
# 732 Episode: Finished after 9 time steps
# 733 Episode: Finished after 10 time steps
# 734 Episode: Finished after 8 time steps
# 735 Episode: Finished after 10 time steps
# 736 Episode: Finished after 8 time steps
# 737 Episode: Finished after 8 time steps
# 738 Episode: Finished after 8 time steps
# 739 Episode: Finished after 10 time steps
# 740 Episode: Finished after 9 time steps
# 741 Episode: Finished after 10 time steps
# 742 Episode: Finished after 9 time steps
# 743 Episode: Finished after 8 time steps
# 744 Episode: Finished after 11 time steps
# 745 Episode: Finished after 10 time steps
# 746 Episode: Finished after 10 time steps
# 747 Episode: Finished after 9 time steps
# 748 Episode: Finished after 10 time steps
# 749 Episode: Finished after 10 time steps
# 750 Episode: Finished after 9 time steps
# 751 Episode: Finished after 8 time steps
# 752 Episode: Finished after 10 time steps
# 753 Episode: Finished after 10 time steps
# 754 Episode: Finished after 10 time steps
# 755 Episode: Finished after 9 time steps
# 756 Episode: Finished after 10 time steps
# 757 Episode: Finished after 9 time steps
# 758 Episode: Finished after 9 time steps
# 759 Episode: Finished after 9 time steps
# 760 Episode: Finished after 9 time steps
# 761 Episode: Finished after 9 time steps
# 762 Episode: Finished after 8 time steps
# 763 Episode: Finished after 8 time steps
# 764 Episode: Finished after 10 time steps
# 765 Episode: Finished after 10 time steps
# 766 Episode: Finished after 10 time steps
# 767 Episode: Finished after 9 time steps
# 768 Episode: Finished after 9 time steps
# 769 Episode: Finished after 9 time steps
# 770 Episode: Finished after 8 time steps
# 771 Episode: Finished after 8 time steps
# 772 Episode: Finished after 8 time steps
# 773 Episode: Finished after 8 time steps
# 774 Episode: Finished after 10 time steps
# 775 Episode: Finished after 9 time steps
# 776 Episode: Finished after 9 time steps
# 777 Episode: Finished after 9 time steps
# 778 Episode: Finished after 10 time steps
# 779 Episode: Finished after 10 time steps
# 780 Episode: Finished after 9 time steps
# 781 Episode: Finished after 10 time steps
# 782 Episode: Finished after 9 time steps
# 783 Episode: Finished after 9 time steps
# 784 Episode: Finished after 8 time steps
# 785 Episode: Finished after 9 time steps
# 786 Episode: Finished after 10 time steps
# 787 Episode: Finished after 11 time steps
# 788 Episode: Finished after 10 time steps
# 789 Episode: Finished after 9 time steps
# 790 Episode: Finished after 10 time steps
# 791 Episode: Finished after 8 time steps
# 792 Episode: Finished after 10 time steps
# 793 Episode: Finished after 10 time steps
# 794 Episode: Finished after 9 time steps
# 795 Episode: Finished after 10 time steps
# 796 Episode: Finished after 8 time steps
# 797 Episode: Finished after 9 time steps
# 798 Episode: Finished after 9 time steps
# 799 Episode: Finished after 10 time steps
# 800 Episode: Finished after 8 time steps
# 801 Episode: Finished after 8 time steps
# 802 Episode: Finished after 10 time steps
# 803 Episode: Finished after 10 time steps
# 804 Episode: Finished after 9 time steps
# 805 Episode: Finished after 8 time steps
# 806 Episode: Finished after 10 time steps
# 807 Episode: Finished after 10 time steps
# 808 Episode: Finished after 9 time steps
# 809 Episode: Finished after 9 time steps
# 810 Episode: Finished after 9 time steps
# 811 Episode: Finished after 9 time steps
# 812 Episode: Finished after 9 time steps
# 813 Episode: Finished after 9 time steps
# 814 Episode: Finished after 9 time steps
# 815 Episode: Finished after 9 time steps
# 816 Episode: Finished after 9 time steps
# 817 Episode: Finished after 10 time steps
# 818 Episode: Finished after 10 time steps
# 819 Episode: Finished after 9 time steps
# 820 Episode: Finished after 10 time steps
# 821 Episode: Finished after 10 time steps
# 822 Episode: Finished after 8 time steps
# 823 Episode: Finished after 8 time steps
# 824 Episode: Finished after 10 time steps
# 825 Episode: Finished after 10 time steps
# 826 Episode: Finished after 10 time steps
# 827 Episode: Finished after 9 time steps
# 828 Episode: Finished after 9 time steps
# 829 Episode: Finished after 10 time steps
# 830 Episode: Finished after 9 time steps
# 831 Episode: Finished after 9 time steps
# 832 Episode: Finished after 10 time steps
# 833 Episode: Finished after 9 time steps
# 834 Episode: Finished after 10 time steps
# 835 Episode: Finished after 10 time steps
# 836 Episode: Finished after 9 time steps
# 837 Episode: Finished after 8 time steps
# 838 Episode: Finished after 8 time steps
# 839 Episode: Finished after 10 time steps
# 840 Episode: Finished after 9 time steps
# 841 Episode: Finished after 11 time steps
# 842 Episode: Finished after 9 time steps
# 843 Episode: Finished after 8 time steps
# 844 Episode: Finished after 10 time steps
# 845 Episode: Finished after 8 time steps
# 846 Episode: Finished after 10 time steps
# 847 Episode: Finished after 9 time steps
# 848 Episode: Finished after 8 time steps
# 849 Episode: Finished after 10 time steps
# 850 Episode: Finished after 10 time steps
# 851 Episode: Finished after 10 time steps
# 852 Episode: Finished after 8 time steps
# 853 Episode: Finished after 8 time steps
# 854 Episode: Finished after 9 time steps
# 855 Episode: Finished after 9 time steps
# 856 Episode: Finished after 10 time steps
# 857 Episode: Finished after 8 time steps
# 858 Episode: Finished after 8 time steps
# 859 Episode: Finished after 10 time steps
# 860 Episode: Finished after 10 time steps
# 861 Episode: Finished after 10 time steps
# 862 Episode: Finished after 9 time steps
# 863 Episode: Finished after 10 time steps
# 864 Episode: Finished after 10 time steps
# 865 Episode: Finished after 10 time steps
# 866 Episode: Finished after 9 time steps
# 867 Episode: Finished after 8 time steps
# 868 Episode: Finished after 9 time steps
# 869 Episode: Finished after 9 time steps
# 870 Episode: Finished after 10 time steps
# 871 Episode: Finished after 9 time steps
# 872 Episode: Finished after 9 time steps
# 873 Episode: Finished after 10 time steps
# 874 Episode: Finished after 8 time steps
# 875 Episode: Finished after 10 time steps
# 876 Episode: Finished after 10 time steps
# 877 Episode: Finished after 10 time steps
# 878 Episode: Finished after 11 time steps
# 879 Episode: Finished after 10 time steps
# 880 Episode: Finished after 9 time steps
# 881 Episode: Finished after 10 time steps
# 882 Episode: Finished after 9 time steps
# 883 Episode: Finished after 10 time steps
# 884 Episode: Finished after 10 time steps
# 885 Episode: Finished after 9 time steps
# 886 Episode: Finished after 10 time steps
# 887 Episode: Finished after 10 time steps
# 888 Episode: Finished after 9 time steps
# 889 Episode: Finished after 8 time steps
# 890 Episode: Finished after 10 time steps
# 891 Episode: Finished after 8 time steps
# 892 Episode: Finished after 11 time steps
# 893 Episode: Finished after 10 time steps
# 894 Episode: Finished after 9 time steps
# 895 Episode: Finished after 9 time steps
# 896 Episode: Finished after 9 time steps
# 897 Episode: Finished after 8 time steps
# 898 Episode: Finished after 10 time steps
# 899 Episode: Finished after 9 time steps
# 900 Episode: Finished after 8 time steps
# 901 Episode: Finished after 10 time steps
# 902 Episode: Finished after 10 time steps
# 903 Episode: Finished after 10 time steps
# 904 Episode: Finished after 9 time steps
# 905 Episode: Finished after 8 time steps
# 906 Episode: Finished after 10 time steps
# 907 Episode: Finished after 10 time steps
# 908 Episode: Finished after 10 time steps
# 909 Episode: Finished after 10 time steps
# 910 Episode: Finished after 10 time steps
# 911 Episode: Finished after 10 time steps
# 912 Episode: Finished after 10 time steps
# 913 Episode: Finished after 9 time steps
# 914 Episode: Finished after 9 time steps
# 915 Episode: Finished after 9 time steps
# 916 Episode: Finished after 8 time steps
# 917 Episode: Finished after 10 time steps
# 918 Episode: Finished after 8 time steps
# 919 Episode: Finished after 9 time steps
# 920 Episode: Finished after 10 time steps
# 921 Episode: Finished after 10 time steps
# 922 Episode: Finished after 9 time steps
# 923 Episode: Finished after 8 time steps
# 924 Episode: Finished after 10 time steps
# 925 Episode: Finished after 9 time steps
# 926 Episode: Finished after 9 time steps
# 927 Episode: Finished after 10 time steps
# 928 Episode: Finished after 10 time steps
# 929 Episode: Finished after 10 time steps
# 930 Episode: Finished after 9 time steps
# 931 Episode: Finished after 8 time steps
# 932 Episode: Finished after 10 time steps
# 933 Episode: Finished after 11 time steps
# 934 Episode: Finished after 9 time steps
# 935 Episode: Finished after 10 time steps
# 936 Episode: Finished after 10 time steps
# 937 Episode: Finished after 9 time steps
# 938 Episode: Finished after 9 time steps
# 939 Episode: Finished after 10 time steps
# 940 Episode: Finished after 9 time steps
# 941 Episode: Finished after 8 time steps
# 942 Episode: Finished after 9 time steps
# 943 Episode: Finished after 9 time steps
# 944 Episode: Finished after 10 time steps
# 945 Episode: Finished after 8 time steps
# 946 Episode: Finished after 8 time steps
# 947 Episode: Finished after 9 time steps
# 948 Episode: Finished after 9 time steps
# 949 Episode: Finished after 10 time steps
# 950 Episode: Finished after 10 time steps
# 951 Episode: Finished after 10 time steps
# 952 Episode: Finished after 10 time steps
# 953 Episode: Finished after 9 time steps
# 954 Episode: Finished after 9 time steps
# 955 Episode: Finished after 10 time steps
# 956 Episode: Finished after 8 time steps
# 957 Episode: Finished after 10 time steps
# 958 Episode: Finished after 11 time steps
# 959 Episode: Finished after 10 time steps
# 960 Episode: Finished after 10 time steps
# 961 Episode: Finished after 10 time steps
# 962 Episode: Finished after 9 time steps
# 963 Episode: Finished after 10 time steps
# 964 Episode: Finished after 9 time steps
# 965 Episode: Finished after 10 time steps
# 966 Episode: Finished after 9 time steps
# 967 Episode: Finished after 9 time steps
# 968 Episode: Finished after 10 time steps
# 969 Episode: Finished after 9 time steps
# 970 Episode: Finished after 9 time steps
# 971 Episode: Finished after 10 time steps
# 972 Episode: Finished after 9 time steps
# 973 Episode: Finished after 9 time steps
# 974 Episode: Finished after 9 time steps
# 975 Episode: Finished after 10 time steps
# 976 Episode: Finished after 8 time steps
# 977 Episode: Finished after 10 time steps
# 978 Episode: Finished after 10 time steps
# 979 Episode: Finished after 9 time steps
# 980 Episode: Finished after 9 time steps
# 981 Episode: Finished after 9 time steps
# 982 Episode: Finished after 9 time steps
# 983 Episode: Finished after 10 time steps
# 984 Episode: Finished after 10 time steps
# 985 Episode: Finished after 10 time steps
# 986 Episode: Finished after 9 time steps
# 987 Episode: Finished after 10 time steps
# 988 Episode: Finished after 10 time steps
# 989 Episode: Finished after 10 time steps
# 990 Episode: Finished after 9 time steps
# 991 Episode: Finished after 10 time steps
# 992 Episode: Finished after 9 time steps
# 993 Episode: Finished after 10 time steps
# 994 Episode: Finished after 10 time steps
# 995 Episode: Finished after 9 time steps
# 996 Episode: Finished after 9 time steps
# 997 Episode: Finished after 9 time steps
# 998 Episode: Finished after 10 time steps
# 999 Episode: Finished after 10 time steps
