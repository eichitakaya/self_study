# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import poisson
import numpy as np

df = pd.read_csv("hoge.csv")
plt.hist(df, range=(-1, 8))
# Out:
# (array([ 0.,  1.,  3., 11., 12., 10.,  5.,  4.,  4.,  0.]),
#  array([-1. , -0.1,  0.8,  1.7,  2.6,  3.5,  4.4,  5.3,  6.2,  7.1,  8. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.arange(0, 9)
p = poisson.pmf(x, df.mean())

# %%
plt.plot(p, marker="o")

# %%
fig, ax = plt.subplots()

ax.set_xlabel("data")
ax.set_ylabel("Frequency")
ax.set_title("Histogram of data")

ax.plot(x, 50 * p, color="black")
ax.hist(df)

ax.set_xlim([-2, 9])

plt.show()
